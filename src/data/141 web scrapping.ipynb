# %%
from urllib2 import Request, urlopen, HTTPError
from urlparse import urlunparse, urlparse
import json 
import pandas as pd
from matplotlib import pyplot as plt
import requests

# %%
from bs4 import BeautifulSoup
import urllib

# %% [markdown]
# <b>Step 1</b> Get the links of different app categories on iTunes.

# %%
r = urllib.urlopen('https://itunes.apple.com/us/genre/ios-books/id6018?mt=8').read()
soup = BeautifulSoup(r)
print type(soup)
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
all_categories = soup.find_all("div", class_="nav")
category_url = all_categories[0].find_all(class_ = "top-level-genre")
categories_url = pd.DataFrame()
for itm in category_url:
    category = itm.get_text()
    url = itm.attrs['href']
    d = {'category':[category], 'url':[url]}
    df = pd.DataFrame(d)
    categories_url = categories_url.append(df, ignore_index = True)
print categories_url
# Out:
#                   category                                                url
# 0                    Books  https://itunes.apple.com/us/genre/ios-books/id...
# 1                 Business  https://itunes.apple.com/us/genre/ios-business...
# 2                 Catalogs  https://itunes.apple.com/us/genre/ios-catalogs...
# 3                Education  https://itunes.apple.com/us/genre/ios-educatio...
# 4            Entertainment  https://itunes.apple.com/us/genre/ios-entertai...
# 5                  Finance  https://itunes.apple.com/us/genre/ios-finance/...
# 6             Food & Drink  https://itunes.apple.com/us/genre/ios-food-dri...
# 7                    Games  https://itunes.apple.com/us/genre/ios-games/id...
# 8         Health & Fitness  https://itunes.apple.com/us/genre/ios-health-f...
# 9                Lifestyle  https://itunes.apple.com/us/genre/ios-lifestyl...
# 10  Magazines & Newspapers  https://itunes.apple.com/us/genre/ios-magazine...
# 11                 Medical  https://itunes.apple.com/us/genre/ios-medical/...
# 12                   Music  https://itunes.apple.com/us/genre/ios-music/id...
# 13              Navigation  https://itunes.apple.com/us/genre/ios-navigati...
# 14                    News  https://itunes.apple.com/us/genre/ios-news/id6...
# 15           Photo & Video  https://itunes.apple.com/us/genre/ios-photo-vi...
# 16            Productivity  https://itunes.apple.com/us/genre/ios-producti...
# 17               Reference  https://itunes.apple.com/us/genre/ios-referenc...
# 18                Shopping  https://itunes.apple.com/us/genre/ios-shopping...
# 19       Social Networking  https://itunes.apple.com/us/genre/ios-social-n...
# 20                  Sports  https://itunes.apple.com/us/genre/ios-sports/i...
# 21                Stickers  https://itunes.apple.com/us/genre/ios-stickers...
# 22                  Travel  https://itunes.apple.com/us/genre/ios-travel/i...
# 23               Utilities  https://itunes.apple.com/us/genre/ios-utilitie...
# 24                 Weather  https://itunes.apple.com/us/genre/ios-weather/...

# %%
categories_url['url'][0]
# Out:
# 'https://itunes.apple.com/us/genre/ios-books/id6018?mt=8'

# %% [markdown]
# <b>Step2</b>
# Get the links for all popular apps of different catigories on iTunes.

# %%
def extract_apps(url):
    r = urllib.urlopen(url).read()
    soup = BeautifulSoup(r)
    apps = soup.find_all("div", class_="column")
    apps_link = apps[0].find_all('a')
    column_first = pd.DataFrame()
    for itm in apps_link:
        app_name = itm.get_text()
        url = itm.attrs['href']
        d = {'category':[app_name], 'url':[url]}
        df = pd.DataFrame(d)
        column_first = column_first.append(df, ignore_index = True)
    apps_link2 = apps[1].find_all('a')
    column_second = pd.DataFrame()
    for itm in apps_link2:
        app_name = itm.get_text()
        url = itm.attrs['href']
        d = {'category':[app_name], 'url':[url]}
        df = pd.DataFrame(d)
        column_second = column_second.append(df, ignore_index = True)
    apps_link3 = apps[2].find_all('a')
    column_last = pd.DataFrame()
    for itm in apps_link3:
        app_name = itm.get_text()
        url = itm.attrs['href']
        d = {'category':[app_name], 'url':[url]}
        df = pd.DataFrame(d)
        column_last = column_last.append(df, ignore_index = True)
    Final_app_link = pd.DataFrame()
    Final_app_link = Final_app_link.append(column_first, ignore_index = True)
    Final_app_link = Final_app_link.append(column_second, ignore_index = True)
    Final_app_link = Final_app_link.append(column_last, ignore_index = True)
    return Final_app_link

# %%
app_url = pd.DataFrame()
for itm in categories_url['url']:
    apps = extract_apps(itm)
    app_url = app_url.append(apps, ignore_index = True)

# %%
app_url['url'][0]
# Out:
# 'https://itunes.apple.com/us/app/kindle-read-ebooks-magazines-textbooks/id302584613?mt=8'

# %% [markdown]
# <b>Step3</b> Extract the information for all popular apps.

# %%
def get_content(url):
    r = urllib.urlopen(url).read()
    soup = BeautifulSoup(r)
    des = soup.find_all('div', id = "content")
    apps = soup.find_all("div", class_="lockup product application")
    rate = soup.find_all("div", class_="extra-list customer-ratings")
    dic = []
    global app_name, descript, link, price, category, current_rate, current_count, total_count, total_rate, seller,mul_dev,mul_lang,new_ver_des
    for itm in des:
        try:
            descript = itm.find_all('div',{'class':"product-review"})[0].get_text().strip().split('\n')[2].encode('utf-8')
        except:
            descript = ''
        try:
            new_ver_des = itm.find_all('div',{'class':"product-review"})[1].get_text().strip().split('\n')[2].encode('utf-8')
        except:
            new_ver_des = ''
        try:
            app_name = itm.find_all('div',{'class':"left" })[0].get_text().split('\n')[1]
        except:
            app_name = ''
    for itm in apps:
        category = itm.find_all('span',{'itemprop':"applicationCategory" })[0].get_text()
        price = itm.find_all('div',{'class':"price" })[0].get_text() 
        link = itm.a["href"]
        seller = itm.find_all("span", itemprop="name")[0].get_text()
        try:
            device = itm.find_all("span", itemprop="operatingSystem")[0].get_text()
            if 'and' in device.lower():
                mul_dev = 'Y'
            else:
                mul_dev = "N"
        except:
            mul_dev = "N"
        try:
            lang = itm.find_all("li",class_ = "language")[0].get_text().split(',')
            if len(lang) >1:
                mul_lang = "Y"
            else:
                mul_lang = "N"
        except:
            mul_lang = "N"
    for itm in rate:
        try:
            current_rate = itm.find_all('span',{'itemprop':"ratingValue"})[0].get_text()
        except:
            current_rate = ''
        try:
            current_count = itm.find_all('span',{'itemprop':"reviewCount"})[0].get_text()
        except:
            current_count = ''
        try:
            total_count = itm.find_all('span',{'class':"rating-count"})[1].get_text()
        except:
            try:
                total_count = itm.find_all('span',{'class':"rating-count"})[0].get_text()
            except:
                total_count = ''
        try:
            total_rate = itm.find_all('div', class_="rating",itemprop = False)[0]['aria-label'].split(',')[0]
        except:
            total_rate = ''
    for i in range(3):
        try:
            globals()['user_{0}'.format(i)] = soup.find_all("div", class_="customer-reviews")[0].find_all("span", class_='user-info')[i].get_text().strip( ).split('  ')[-1]
        except:
            globals()['user_{0}'.format(i)] = ''
        try:
            globals()['star_{0}'.format(i)] = soup.find_all("div", class_="customer-reviews")[0].find_all("div", class_="rating")[i]['aria-label']
        except:
            globals()['star_{0}'.format(i)] = ''
        try:
            globals()['comm_{0}'.format(i)] = soup.find_all("div", class_="customer-reviews")[0].find_all("p", class_="content")[i].get_text()
        except:
            globals()['comm_{0}'.format(i)] = ''
       
    dic.append({'app':app_name,'link':link, 'price':price,'category':category,'current rating':current_rate, 
                'current reviews':current_count,'overall rating':total_rate,'overall reviews':total_count,
                'description':descript,'seller':seller,'multiple languages':mul_lang,
                'multiple devices':mul_dev,'new version description':new_ver_des,'user 1':user_0,
                'rate 1':star_0,'comment 1':comm_0,'user 2':user_1,'rate 2':star_1,'comment 2':comm_1,
                'user 3':user_2,'rate 3':star_2,'comment 3':comm_2})
    dic = pd.DataFrame(dic)
    return dic

# %%
full_content = pd.DataFrame()
for itm in app_url['url']:
    content = get_content(itm)
    full_content = full_content.append(content, ignore_index = True)

# %%
full_content
# Out:
#                                                     app category  \
# 0           Kindle – Read eBooks, Magazines & Textbooks    Books
# 1     Audible – audio books, original series & podcasts    Books
# 2                 Wattpad - Free Books and eBook Reader    Books
# 3     NOOK - Read Books, Magazines, Newspapers & Comics    Books
# 4                                 HOOKED - Chat Stories    Books
# 5             OverDrive – Library eBooks and Audiobooks    Books
# 6          Goodreads – Book Recommendations and Reviews    Books
# 7                    Google Play Books - Books & Comics    Books
# 8      Scribd - Books, audiobooks, magazines, documents    Books
# 9                                            Audiobooks    Books
# 10                                        Marvel Comics    Books
# 11                            Audio Books by Audiobooks    Books
# 12    Tips & Tricks - Secrets for iPhone (Free Edition)    Books
# 13                  The Holy Bible - King James Version    Books
# 14                        Kobo Reading App – Read Books    Books
# 15                                       Barnes & Noble    Books
# 16                               18,000 COOL JOKES FREE    Books
# 17               Free Books - Ultimate Classics Library    Books
# 18    Color Therapy Free Adult Coloring Book for Adults    Books
# 19                                       Weird But True    Books
# 20    Weird Facts 1000! Fun, Random, Interesting, Tr...    Books
# 21                                            DC Comics    Books
# 22        eBook Search - Free books for iBooks and more    Books
# 23    Love Quotes and Sayings! Daily Romantic Valent...    Books
# 24                                         Ebook Reader    Books
# 25    Books - 23,469 Classics To Go. The Ultimate Eb...    Books
# 26                   Tips for iPhone - Tricks & Secrets    Books
# 27                                       Hoopla Digital    Books
# 28    MeeGenius Children’s Books:  Storybooks + Song...    Books
# 29              Manga Storm - The Ultimate Manga Reader    Books
# ...                                                 ...      ...
# 5970                    KOCO 5 News First Alert Weather  Weather
# 5971                                            WSMV WX  Weather
# 5972                      WSOC-TV Channel 9 Weather App  Weather
# 5973                            NOAA Buoy and Tide Data  Weather
# 5974           SkyTower Radar app from FOX 13 Tampa Bay  Weather
# 5975                         NOAA Weather International  Weather
# 5976                     WIS News 10 FirstAlert Weather  Weather
# 5977                                         حالة الطقس  Weather
# 5978                                           9NEWS WX  Weather
# 5979                                      Gismeteo lite  Weather
# 5980    My Tide Times - Tide Tables, Forecasts & Tides!  Weather
# 5981                                 Best Hunting Times  Weather
# 5982                                             Rainly  Weather
# 5983                       KCRG-TV9 First Alert Weather  Weather
# 5984      Lunar Calendar & Biorhythm - The Moon Planner  Weather
# 5985    WKRN WX - News 2 StormTracker Nashville weather  Weather
# 5986                                   Fox8 Max Weather  Weather
# 5987                             WTOC First Alert Radar  Weather
# 5988                                               天气预报  Weather
# 5989                                  天气通 - 关注天气，开启美好生活  Weather
# 5990            WNEP Stormtracker 16 - Scranton Weather  Weather
# 5991                          Rain Alarm - Radar & Push  Weather
# 5992                              KAIT Region 8 Weather  Weather
# 5993                                         منبه الطقس  Weather
# 5994                                     ATsWeatherToGo  Weather
# 5995       Weather Mate - Forecast, Radar, Maps, Alerts  Weather
# 5996   Your Weather Authority for South Texas - KSAT 12  Weather
# 5997                                       WeatherWheel  Weather
# 5998                             EPA's SunWise UV Index  Weather
# 5999    My Aurora Forecast - Northern Lights & Borealis  Weather
#
#                                               comment 1  \
# 0     \n    Please focus on reading and listening ex...
# 1     \n    It's very enjoyable to be able to listen...
# 2     \n    I am absolutely *in love* with Wattpad. ...
# 3     \n    I would give it 5 stars if the App would...
# 4     \n    Keeps you on the edge of your seat. If y...
# 5     \n    I don't ever write reviews, but I derive...
# 6     \n    I like tracking the books I've read. I a...
# 7     \n    This is the WORST Ereader I have ever us...
# 8     \n    Scribd is a fairly good service (now onl...
# 9     \n    I had it on my iPhone 2, my iPhone 4 and...
# 10    \n    I've been using this app for a couple of...
# 11    \n    And audiobooks are great for my busy lif...
# 12    \n    News feeds of info about Apple products,...
# 13    \n    I love this Bible app and use it daily. ...
# 14    \n    The new update is terrible. It takes for...
# 15    \n    I love BN with everything in me. However...
# 16    \n    It's hard to tell whether this app is wo...
# 17    \n    First, this app has little relationship ...
# 18    \n    After reviewing the lengthy list of apps...
# 19    \n    Well lots of people (including me) are s...
# 20    \n    I got this app probably five years ago, ...
# 21    \n    ******************Update****************...
# 22    \n    Just began using this app; so far I've b...
# 23    \n    This app isn't a game, but it's very gre...
# 24    \n    I love that I can send a copy of my Eboo...
# 25    \n    Months later, still not fixed. The devel...
# 26    \n    If this app told me the recipe to cure c...
# 27    \n    I love that my library grants access to ...
# 28    \n    The craters of this app are so thoughtfu...
# 29    \n    If you're looking for a Manga Reader, lo...
# ...                                                 ...
# 5970
# 5971
# 5972
# 5973  \n    I use this app various times throughout ...
# 5974
# 5975  \n    The app does provide the detailed foreca...
# 5976
# 5977               \n    البرنامج جميل وبواجهة اجمل\n
# 5978  \n    I would've given this app five stars unt...
# 5979  \n    Справляется отлично со своей задачей, по...
# 5980  \n    Gives times for high and low tides. Very...
# 5981  \n    I love this Ap it is always very accurat...
# 5982  \n    I just downloaded this app when I notice...
# 5983
# 5984  \n    It's alright. I liked it till I had to u...
# 5985  \n    9/10 times I open the app I'm stuck with...
# 5986
# 5987
# 5988                                   \n    Great!\n
# 5989
# 5990
# 5991
# 5992
# 5993
# 5994  \n    After moving to OK from Cali where I nev...
# 5995  \n    This is an unbelievably comprehensive ye...
# 5996
# 5997  \n    I love this app. It has a beautiful inte...
# 5998  \n    This is a good UV index app however ther...
# 5999  \n    Can't thank this app and the dev's enoug...
#
#                                               comment 2  \
# 0     \n    I can't believe they added a clock in th...
# 1     \n    Works great 99% of the time. When it did...
# 2     \n    I love this app sooo much I won't be abl...
# 3     \n    Glad to have Nook on my iPad but wish ma...
# 4     \n    It's a great app and I love the chills (...
# 5     \n    Love this app. With two kids, this makes...
# 6     \n    Great app for book readers. Have no comp...
# 7     \n    Updated Updated Review: The latest updat...
# 8     \n    I really like this app but I just don't ...
# 9     \n    I really really like this app and I use ...
# 10    \n    A digital comic is not the same as the p...
# 11    \n    I live on the outskirts of Los Angeles a...
# 12    \n    I'm always finding something new on this...
# 13    \n    This Bible app is a blessing. The fact t...
# 14    \n    Please go back to allowing purchases dir...
# 15    \n    If I wanted a web app, I'd use your mobi...
# 16    \n    I used to love this app, then I got an u...
# 17    \n    Nearly all the books lack any sort of de...
# 18    \n    For the most part I enjoy the wide varie...
# 19    \n    Personally, I love the weird but true bo...
# 20    \n    I just got this app and I already love i...
# 21    \n    The reader part of this application is g...
# 22    \n    I've looked for an app that lets me sear...
# 23    \n    I've had this app for a long time, and I...
# 24    \n    I tried to open a pdf file from google d...
# 25    \n    My review is exactly like the first one....
# 26    \n    Understandably easy quick tips to help y...
# 27    \n    I guess it's an okay compromise when you...
# 28    \n    Worked for a short period of time. Then ...
# 29    \n    A side note to those, complaining that y...
# ...                                                 ...
# 5970
# 5971
# 5972
# 5973  \n    I am not sure why this app is getting so...
# 5974
# 5975  \n    NOAA Weather International is a wonderfu...
# 5976
# 5977                  \n    استاهل خير خل سعره 0.99\n
# 5978  \n    Complete fail in weather map past/future...
# 5979  \n    Объясните фразу: малооблачно, дождь, гро...
# 5980  \n    Accurate, and useful.  Great for those f...
# 5981  \n    Hunting times are about dead on. Except ...
# 5982  \n    Huh?  There is no temperature displayed....
# 5983
# 5984  \n    Just the free version shows good graphs....
# 5985
# 5986
# 5987
# 5988                                     \n    good\n
# 5989
# 5990
# 5991
# 5992
# 5993
# 5994  \n    AT's Weather is quick but mostly it's re...
# 5995  \n    Multiple tornadoes have been confirmed i...
# 5996
# 5997
# 5998  \n    This app displays the current UV forecas...
# 5999  \n    Using the KP and the cloud coverage, we ...
#
#                                               comment 3 current rating  \
# 0     \n    You guys did an amazing job updating it ...        2.65152
# 1     \n    Audiobooks are a little bit expensive, b...        4.65113
# 2     \n    I love wattpad! I really do! It's my fav...        4.59425
# 3     \n    I love reading books electronically. Hav...        4.33955
# 4     \n    I just got through the first three parte...        4.54263
# 5     \n    I listen to audiobooks from overdrive on...        4.35417
# 6     \n    I had to use goodreads in a class to kee...        4.51875
# 7     \n    Google Play Books has an incredible sele...        4.53308
# 8                                                              3.85714
# 9     \n    I love this app and have used it for abo...        3.55224
# 10    \n    Marvel has made an app where I can read ...        2.64516
# 11    \n    Love this app for listening to my favori...           4.82
# 12    \n    App looks interesting and might have som...        3.83333
# 13    \n    The only thing that could possibly impro...            4.0
# 14    \n    interface is worse than ibooks in every ...           3.25
# 15    \n    I downloaded the app today because I sig...        1.32292
# 16    \n    Jokes in this app are not that great. A ...        3.21429
# 17    \n    After latest update they improved many t...        2.45545
# 18    \n    This app is fantastic. They constantly a...        4.70906
# 19    \n    You only get a few facts to start with. ...        2.48387
# 20    \n    I love reading all these facts. I came a...        3.99301
# 21    \n    I use the app the catch up on books that...        3.06897
# 22    \n    Easy to use, lots of books, several down...        4.40909
# 23    \n    You won't imagine how great this app is....        4.28571
# 24    \n    Does what it's supposed to do, and is fr...            4.0
# 25    \n    This app is as close to perfection as yo...        2.98276
# 26    \n    This app offers some nice tips and trick...        3.33929
# 27    \n    I like this app overall, primarily becau...        4.00575
# 28    \n    App kept crashing but customer support w...        3.71233
# 29    \n    Anyone who's a fan of manga should get t...        4.86347
# ...                                                 ...            ...
# 5970
# 5971
# 5972
# 5973
# 5974
# 5975  \n    Super app very accurate very,very accura...        4.33333
# 5976
# 5977     \n    البرنامج اكثر من رائع ويستاهل 5 نجوم\n          4.66667
# 5978
# 5979                                                               3.9
# 5980  \n    Living on the water in village harbor/Th...        4.85714
# 5981  \n    Great App. Has not been updated in a whi...        4.11111
# 5982  \n    this app is cute but why does it say nul...
# 5983
# 5984  \n    Need to be able to add another subject. ...        4.09999
# 5985
# 5986
# 5987
# 5988                                                               5.0
# 5989
# 5990
# 5991
# 5992
# 5993
# 5994  \n    Best weather App out there!  I've tried ...        4.19998
# 5995  \n    There is times that my work requires me ...        4.41667
# 5996
# 5997
# 5998  \n    I originally had a problem with this app...            3.0
# 5999  \n    Very nice app, with notification of high...            4.9
#
#      current reviews                                        description  \
# 0         66 Ratings  Turn your iPhone or iPad into a Kindle with th...
# 1       1995 Ratings  Welcome to Audible. We’re an Amazon company, a...
# 2        313 Ratings  Discover Wattpad:At Wattpad, we’re connecting ...
# 3       1072 Ratings  Get the FREE NOOK Reading App for your iPad, i...
# 4        129 Ratings  HOOKED lets you read amazing chat stories FREE...
# 5         48 Ratings  Borrow eBooks, audiobooks, and streaming video...
# 6        160 Ratings  Discover and share books you love on Goodreads...
# 7       1058 Ratings  With Google Play Books for iOS start reading t...
# 8          7 Ratings  Are you ready for access to the best books, au...
# 9         67 Ratings  Thousands of FREE audiobooks await. Whether yo...
# 10        31 Ratings  Introducing the MARVEL COMICS app, a revolutio...
# 11        50 Ratings  The hottest titles, the coolest features, and ...
# 12        12 Ratings  This is the App that should come installed on ...
# 13        22 Ratings  The Holy Bible - King James Version is a beaut...
# 14         8 Ratings  Millions of readers love Kobo! Join them today...
# 15        96 Ratings  Put the World’s Largest Bookstore on your iPho...
# 16       154 Ratings  World's most admired jokes app for over 4 year...
# 17       101 Ratings  All books to read completely for FREE.This leg...
# 18       629 Ratings  Color Therapy is #1 Adult Coloring App/Book in...
# 19       155 Ratings  * Winner of Spring 2012 Parents’ Choice Funstu...
# 20       143 Ratings  Tons of cool, weird, useless, odd & awesome fu...
# 21        29 Ratings  DC Entertainment is one of the largest English...
# 22        88 Ratings  ***** Over 4,300 5-star ratingsIf you’d like a...
# 23        35 Ratings  Best Love Quotes at your fingertips!Want to in...
# 24        34 Ratings  eBooks.com's Ebook Reader lets you read your f...
# 25        58 Ratings  Like reading? Fire up our Books app and downlo...
# 26       112 Ratings  ** If you are experiencing issues after updati...
# 27       522 Ratings  Instantly borrow free digital movies, music, e...
# 28        73 Ratings  Nurture your child’s love for reading with thi...
# 29       542 Ratings  Looking for a nice app to *Read* and *Follow* ...
# ...              ...                                                ...
# 5970                  The all-new KOCO 5 News First Alert Weather Ap...
# 5971                  WSMV Weather is proud to announce a full featu...
# 5972                  Chief Meteorologist Steve Udelson and Severe W...
# 5973                  The first and still the best, NOAA Buoy and Ti...
# 5974                  Get the power of FOX 13's SkyTower Radar on yo...
# 5975      21 Ratings  Retrieve real-time 7-day hyperlocal point weat...
# 5976                  The WIS Mobile Weather App includes:   * Acces...
# 5977       9 Ratings  حالة الطقس هو أول تطبيق عربي باللغة العربية في...
# 5978                  9News in Denver, Colorado is  proud to present...
# 5979      10 Ratings  An official weather app by Gismeteo.Key featur...
# 5980       7 Ratings  My Tide Times is the only tide times applicati...
# 5981       9 Ratings  The #1 solunar table app for iPhone. Monthly v...
# 5982                  Free for a limited time!Rainly - Rediscover th...
# 5983                  The KCRG Mobile Weather App includes:   * Acce...
# 5984      10 Ratings  From AustraliaTop app - by HeavensppA+++From B...
# 5985                  Never let the weather catch you by surprise ag...
# 5986                  The WGHP Mobile Weather App includes:   * Acce...
# 5987                  The WTOC Mobile Weather App includes:   * Acce...
# 5988      13 Ratings  天气预报：出行必备利器！提供优质的气象预报服务！全球亿万用户的共同选择！  * 长达10日的...
# 5989                  最专业最贴心的天气APP，3.8亿用户的选择，采用权威多数据源授权信息，智能纠错，国内300...
# 5990                  The WNEP Mobile Weather App includes:   • Acce...
# 5991                  Don't get caught in the rain!Fed up with incor...
# 5992                  The KAIT Mobile Weather App includes:   * Acce...
# 5993                  يقوم تطبيق منبه الطقس بتنبيهك يوميا بالحاله ال...
# 5994       5 Ratings  6 Reasons why you should try the ‘ATsWeatherTo...
# 5995      24 Ratings  Say Hello to your new Mate - Weather Mate. The...
# 5996                  The KSAT Weather app brings you the latest wea...
# 5997                  Spin the wheel and watch the weather changing ...
# 5998      20 Ratings  The UV Index provides a daily and hourly forec...
# 5999      10 Ratings  My Aurora Forecast is the best app for seeing ...
#
#                                                    link multiple devices  \
# 0     https://itunes.apple.com/us/app/kindle-read-eb...                Y
# 1     https://itunes.apple.com/us/app/audible-audio-...                Y
# 2     https://itunes.apple.com/us/app/wattpad-free-b...                Y
# 3     https://itunes.apple.com/us/app/nook-read-book...                Y
# 4     https://itunes.apple.com/us/app/hooked-chat-st...                Y
# 5     https://itunes.apple.com/us/app/overdrive-libr...                Y
# 6     https://itunes.apple.com/us/app/goodreads-book...                Y
# 7     https://itunes.apple.com/us/app/google-play-bo...                Y
# 8     https://itunes.apple.com/us/app/scribd-books-a...                Y
# 9     https://itunes.apple.com/us/app/audiobooks/id3...                Y
# 10    https://itunes.apple.com/us/app/marvel-comics/...                Y
# 11    https://itunes.apple.com/us/app/audio-books-by...                Y
# 5991                                                       Carlos Aviles
# 5992                                                   Raycom Media, Inc
# 5993                                                       Raja' Ibrahim
# 5994  5 stars  5 stars  5 stars                             Aaron Tuttle
# 5995  5 stars  5 stars  5 stars                      DylogicApps Pvt Ltd
# 5996                                             Graham Media Group, Inc
# 5997  5 stars                                              Lukas Boehler
# 5998  4 stars  4 stars  4 stars          Environmental Protection Agency
# 5999  5 stars  5 stars  5 stars                              Jake Ruston
#
#                     user 1                user 2                  user 3
# 0         LambdaExpression               Lorring                Prellvis
# 1              Smuckitelly         Scorchedterra                 vtalbot
# 2                 dg2017xx         RedPandaWorld               Kajdisksn
# 3          Morgan737364737        Too old to tap                Rstocky7
# 4     100% Honest Feedback               Abbidon       Gangrel_Bloodfang
# 5               Blasterbob  Morbidity, Revisited          Ginastudysmart
# 6                  Zanykfc            Blueocean7        GotSomeSplaining
# 7                attyjames               schoowa               John Hahn
# 8                  bfchris             Pata17931
# 9                    Ambjg              123Meier             Nikravesous
# 10               Skinnydad   Digital vs. Printed       The coolest Aidan
# 11                IssyPooh     Chloececiliajonas               Jkitten12
# 12                Beep2014           Leese' Blue                  Zebram
# 13                Omninico       A Senior Pastor                slward78
# 14            Poor design.              Jenny4OU  Eopidiakiakioll1234321
# 15         SincerelyKaySea         someone929292           Rochesterjeff
# 16                  RonG69         Quantamamalee              D's Kitten
# 17          Sodapop04282us                 Autsy           Newporter1406
# 18             NotedSinger              Cat'Isha          ArwenEvenStar2
# 19          Lilbudderlover            PeakA&Pals                 Emerasd
# 20                 chefmav             Awarren79          Oopsys said...
# 21                  Drak82            Paul in NY                 K3vinP1
# 22          Tony48greenbay      Galen Bradwarden            Hfs furthers
# 23                cmrdauer                Kofo.Z                Luee Jay
# 24                 Liz_Mic         HeylinEclipse          mighty roxtard
# 25              FishyFlake               Hnysbny             Chrisgrey39
# 26              Sky Blue G                Phen!x                 Adameze
# 27             Real Newbie             Dude0u812           River.Phoenix
# 28        Loveee rhadielys        ericscottadams                 Deetttt
# 29                   Orcuh            Somedude90              Bookster64
# ...                    ...                   ...                     ...
# 5970
# 5971
# 5972
# 5973     Jays Gone Fishing             tmccabejr
# 5974
# 5975              xWARSAWx           Michael3129            Blue wolf 47
# 5976
# 5977           Ahmad1988sa           Boabdalaziz               Qamar2013
# 5978             Kbullfish            Mermaid998
# 5979              iEgorovy                Bax386
# 5980            Sierra2965              ELOYHERE               Downtownv
# 5981              Twoehler            Comeerdeer              Hunt Smart
# 5982              LBSparky    Real Music-Not Rap               asapmalik
# 5983
# 5984      Phoenix R. Smith                 Ozhma               trkral364
# 5985            Reallyjosh
# 5986
# 5987
# 5988                   枫咏王                iyumen
# 5989
# 5990
# 5991
# 5992
# 5993
# 5994      Mrskaylawilliams              Dip crap                   IASAI
# 5995           Daveber0002             BabyMan83           HorseshoerDan
# 5996
# 5997           Don't Buy 0
# 5998               jman13!               I_cycle                    DMIA
# 5999          PlayaHermosa               tomtkao                 Aoumvin
#
# [6000 rows x 22 columns]

# %%
full_content.to_csv('app.csv',encoding='utf-8',index=True)
